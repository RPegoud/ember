# %%
from lightning import Fabric
import torch
from ember import Transformer

# %%
f = Fabric()
f.launch()

# %%
d = f.load("ember/llm/checkpoints/2025_12_16__14_43/best_loss=10.2641_2025_12_16__14_43.ckpt")
model = d["model"]

# %%
from huggingface_hub import upload_folder

# %%
m = Transformer()
# Out:
# OrderedDict([('embed.weight',
#               tensor([[ 0.0125, -0.0199, -0.0368,  ...,  0.0266,  0.0019,  0.0080],
#                       [-0.0030, -0.0038,  0.0275,  ..., -0.0029,  0.0088,  0.0185],
#                       [ 0.0079, -0.0008,  0.0359,  ...,  0.0002, -0.0117,  0.0022],
#                       ...,
#                       [-0.0086, -0.0003,  0.0032,  ..., -0.0011, -0.0109, -0.0027],
#                       [ 0.0128, -0.0130,  0.0074,  ..., -0.0149, -0.0251, -0.0065],
#                       [-0.0241,  0.0128, -0.0064,  ...,  0.0022,  0.0048,  0.0063]])),
#              ('attn_blocks.0.mlp.W.weight',
#               tensor([[ 1.8719e-02,  4.4490e-04,  2.1726e-02,  ..., -1.0983e-03,
#                         1.3810e-02,  1.1647e-02],
#                       [ 2.8240e-03,  5.5497e-04, -5.0325e-03,  ...,  1.9854e-02,
#                        -9.1433e-05,  7.2985e-04],
#                       [ 8.7687e-03,  1.1646e-02,  1.0700e-02,  ...,  2.6076e-02,
# ...
